# %% [markdown]
# ## Downloading Images from Bing and Saving them to Google Drive
#
# In this notebook, we download images from Bing Image Search and save them to Google Drive.

# %%
# !pip install bing-image-downloader

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
from pathlib import Path
import os
from bing_image_downloader import downloader

# Important: the shared folder doesn't have the 'workbench_' prefix on its path
# folder_path = Path('/gdrive/MyDrive/image_dataset_curation_workshop_3/raw_data')

folder_path = Path('/gdrive/MyDrive/workbench_image_dataset_curation_workshop_3/raw_data')
os.listdir(folder_path)
# Out:
# []

# %%
# this will create the folder
downloader.download("female_lion", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# [%] Downloading Images to /gdrive/MyDrive/image_dataset_curation_workshop_3/raw_data/female_lion
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images.unsplash.com/photo-1470239313878-0d1de9d85508?ixlib=rb-1.2.1&amp;ixid=eyJhcHBfaWQiOjEyMDd9&amp;w=1000&amp;q=80
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/b3/ce/f3/b3cef33fb5f0bbfb91687096cee47ae7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://3.bp.blogspot.com/-maodaqLQRBI/T7z8Vwy9dkI/AAAAAAAACtM/bVU5wGaZd_E/s1600/female+lion+pictures+4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/65/a1/d7/65a1d7bdb9e13db8122d4d581bcc38ab.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.wallpaperflare.com/static/184/683/726/lion-lioness-rocks-grass-wallpaper.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("male_lion", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 5 Images on Page 42720.
#
# ...
#
#
#
# [!!]Indexing page: 42721
#
# [%] Indexed 5 Images on Page 42721.
#
# ...
#
#
#
# [!!]Indexing page: 42722
#
# [%] Indexed 5 Images on Page 42722.
#
# ...
#
#
#
# [!!]Indexing page: 42723
#
# [%] Indexed 5 Images on Page 42723.
#
# ...
#
#
#
# [!!]Indexing page: 42724
#
# [%] Indexed 5 Images on Page 42724.
#
# ...
#
#
#
# [!!]Indexing page: 42725
#
# [%] Indexed 5 Images on Page 42725.
#
# ...
#
#
#
# [!!]Indexing page: 42726
#
# [%] Indexed 5 Images on Page 42726.
#
# ...
#
#
#
# [!!]Indexing page: 42727
#
# [%] Indexed 5 Images on Page 42727.
#
# ...
#
#
#
# [!!]Indexing page: 42728
#
# [%] Indexed 5 Images on Page 42728.
#
# ...
#
#
#
# [!!]Indexing page: 42729
#
# [%] Indexed 5 Images on Page 42729.
#
# ...
#
#
#
# [!!]Indexing page: 42730
#
# [%] Indexed 5 Images on Page 42730.
#
# ...
#
#
#
# [!!]Indexing page: 42731
#
# [%] Indexed 5 Images on Page 42731.
#
# ...
#
#
#
# [!!]Indexing page: 42732
#
# [%] Indexed 5 Images on Page 42732.
#
# ...
#
#
#
# ...

# %%
downloader.download("boar", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
# [%] Indexed 28 Images on Page 36310.
#
# ...
#
#
#
# [!!]Indexing page: 36311
#
# [%] Indexed 28 Images on Page 36311.
#
# ...
#
#
#
# [!!]Indexing page: 36312
#
# [%] Indexed 28 Images on Page 36312.
#
# ...
#
#
#
# [!!]Indexing page: 36313
#
# [%] Indexed 28 Images on Page 36313.
#
# ...
#
#
#
# [!!]Indexing page: 36314
#
# [%] Indexed 28 Images on Page 36314.
#
# ...
#
#
#
# [!!]Indexing page: 36315
#
# [%] Indexed 15 Images on Page 36315.
#
# ...
#
#
#
# [!!]Indexing page: 36316
#
# [%] Indexed 15 Images on Page 36316.
#
# ...
#
#
#
# [!!]Indexing page: 36317
#
# [%] Indexed 28 Images on Page 36317.
#
# ...
#
#
#
# [!!]Indexing page: 36318
#
# [%] Indexed 28 Images on Page 36318.
#
# ...
#
#
#
# [!!]Indexing page: 36319
#
# [%] Indexed 28 Images on Page 36319.
#
# ...
#
#
#
# [!!]Indexing page: 36320
#
# [%] Indexed 28 Images on Page 36320.
#
# ...
#
#
#
# [!!]Indexing page: 36321
#
# [%] Indexed 28 Images on Page 36321.
#
# ...
#
#
#
# [!!]Indexing page: 36322
#
# ...

# %%
downloader.download("lion_cub", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [!!]Indexing page: 12267
#
# [%] Indexed 10 Images on Page 12267.
#
# ...
#
#
#
# [!!]Indexing page: 12268
#
# [%] Indexed 10 Images on Page 12268.
#
# ...
#
#
#
# [!!]Indexing page: 12269
#
# [%] Indexed 10 Images on Page 12269.
#
# ...
#
#
#
# [!!]Indexing page: 12270
#
# [%] Indexed 10 Images on Page 12270.
#
# ...
#
#
#
# [!!]Indexing page: 12271
#
# [%] Indexed 10 Images on Page 12271.
#
# ...
#
#
#
# [!!]Indexing page: 12272
#
# [%] Indexed 10 Images on Page 12272.
#
# ...
#
#
#
# [!!]Indexing page: 12273
#
# [%] Indexed 5 Images on Page 12273.
#
# ...
#
#
#
# [!!]Indexing page: 12274
#
# [%] Indexed 10 Images on Page 12274.
#
# ...
#
#
#
# [!!]Indexing page: 12275
#
# [%] Indexed 10 Images on Page 12275.
#
# ...
#
#
#
# [!!]Indexing page: 12276
#
# [%] Indexed 10 Images on Page 12276.
#
# ...
#
#
#
# [!!]Indexing page: 12277
#
# [%] Indexed 5 Images on Page 12277.
#
# ...
#
#
#
# [!!]Indexing page: 12278
#
# [%] Indexed 10 Images on Page 12278.
#
# ...
#
#
#
# [!!]Indexing page: 12279
#
# ...

# %%
downloader.download("lion_hunt_eugene_delacroix", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [!!]Indexing page: 2823
#
# [%] Indexed 35 Images on Page 2823.
#
# ...
#
#
#
# [!!]Indexing page: 2824
#
# [%] Indexed 35 Images on Page 2824.
#
# ...
#
#
#
# [!!]Indexing page: 2825
#
# [%] Indexed 35 Images on Page 2825.
#
# ...
#
#
#
# [!!]Indexing page: 2826
#
# [%] Indexed 35 Images on Page 2826.
#
# ...
#
#
#
# [!!]Indexing page: 2827
#
# [%] Indexed 35 Images on Page 2827.
#
# ...
#
#
#
# [!!]Indexing page: 2828
#
# [%] Indexed 23 Images on Page 2828.
#
# ...
#
#
#
# [!!]Indexing page: 2829
#
# [%] Indexed 35 Images on Page 2829.
#
# ...
#
#
#
# [!!]Indexing page: 2830
#
# [%] Indexed 35 Images on Page 2830.
#
# ...
#
#
#
# [!!]Indexing page: 2831
#
# [%] Indexed 35 Images on Page 2831.
#
# ...
#
#
#
# [!!]Indexing page: 2832
#
# [%] Indexed 35 Images on Page 2832.
#
# ...
#
#
#
# [!!]Indexing page: 2833
#
# [%] Indexed 35 Images on Page 2833.
#
# ...
#
#
#
# [!!]Indexing page: 2834
#
# [%] Indexed 35 Images on Page 2834.
#
# ...
#
#
#
# [!!]Indexing page: 2835
#
# ...

# %%
downloader.download("lion_resting_turned_to_the_left_rembrandt", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [!!]Indexing page: 10988
#
# [%] Indexed 7 Images on Page 10988.
#
# ...
#
#
#
# [!!]Indexing page: 10989
#
# [%] Indexed 21 Images on Page 10989.
#
# ...
#
#
#
# [!!]Indexing page: 10990
#
# [%] Indexed 21 Images on Page 10990.
#
# ...
#
#
#
# [!!]Indexing page: 10991
#
# [%] Indexed 21 Images on Page 10991.
#
# ...
#
#
#
# [!!]Indexing page: 10992
#
# [%] Indexed 21 Images on Page 10992.
#
# ...
#
#
#
# [!!]Indexing page: 10993
#
# [%] Indexed 7 Images on Page 10993.
#
# ...
#
#
#
# [!!]Indexing page: 10994
#
# [%] Indexed 7 Images on Page 10994.
#
# ...
#
#
#
# [!!]Indexing page: 10995
#
# [%] Indexed 7 Images on Page 10995.
#
# ...
#
#
#
# [!!]Indexing page: 10996
#
# [%] Indexed 21 Images on Page 10996.
#
# ...
#
#
#
# [!!]Indexing page: 10997
#
# [%] Indexed 21 Images on Page 10997.
#
# ...
#
#
#
# [!!]Indexing page: 10998
#
# [%] Indexed 24 Images on Page 10998.
#
# ...
#
#
#
# [!!]Indexing page: 10999
#
# [%] Indexed 21 Images on Page 10999.
#
# ...
#
#
#
# [!!]Indexing page: 11000
#
# ...

# %%
downloader.download("sleeping_gipsy_henri_rousseau", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [!!]Indexing page: 18876
#
# [%] Indexed 27 Images on Page 18876.
#
# ...
#
#
#
# [!!]Indexing page: 18877
#
# [%] Indexed 27 Images on Page 18877.
#
# ...
#
#
#
# [!!]Indexing page: 18878
#
# [%] Indexed 11 Images on Page 18878.
#
# ...
#
#
#
# [!!]Indexing page: 18879
#
# [%] Indexed 21 Images on Page 18879.
#
# ...
#
#
#
# [!!]Indexing page: 18880
#
# [%] Indexed 27 Images on Page 18880.
#
# ...
#
#
#
# [!!]Indexing page: 18881
#
# [%] Indexed 27 Images on Page 18881.
#
# ...
#
#
#
# [!!]Indexing page: 18882
#
# [%] Indexed 27 Images on Page 18882.
#
# ...
#
#
#
# [!!]Indexing page: 18883
#
# [%] Indexed 27 Images on Page 18883.
#
# ...
#
#
#
# [!!]Indexing page: 18884
#
# [%] Indexed 27 Images on Page 18884.
#
# ...
#
#
#
# [!!]Indexing page: 18885
#
# [%] Indexed 11 Images on Page 18885.
#
# ...
#
#
#
# [!!]Indexing page: 18886
#
# [%] Indexed 27 Images on Page 18886.
#
# ...
#
#
#
# [!!]Indexing page: 18887
#
# [%] Indexed 27 Images on Page 18887.
#
# ...
#
#
#
# [!!]Indexing page: 18888
#
# ...

# %%
downloader.download("lion_rosa_bonheur", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# [!!]Indexing page: 2027
#
# [%] Indexed 18 Images on Page 2027.
#
# ...
#
#
#
# [!!]Indexing page: 2028
#
# [%] Indexed 3 Images on Page 2028.
#
# ...
#
#
#
# [!!]Indexing page: 2029
#
# [%] Indexed 18 Images on Page 2029.
#
# ...
#
#
#
# [!!]Indexing page: 2030
#
# [%] Indexed 18 Images on Page 2030.
#
# ...
#
#
#
# [!!]Indexing page: 2031
#
# [%] Indexed 18 Images on Page 2031.
#
# ...
#
#
#
# [!!]Indexing page: 2032
#
# [%] Indexed 18 Images on Page 2032.
#
# ...
#
#
#
# [!!]Indexing page: 2033
#
# [%] Indexed 3 Images on Page 2033.
#
# ...
#
#
#
# [!!]Indexing page: 2034
#
# [%] Indexed 18 Images on Page 2034.
#
# ...
#
#
#
# [!!]Indexing page: 2035
#
# [%] Indexed 18 Images on Page 2035.
#
# ...
#
#
#
# [!!]Indexing page: 2036
#
# [%] Indexed 18 Images on Page 2036.
#
# ...
#
#
#
# [!!]Indexing page: 2037
#
# [%] Indexed 18 Images on Page 2037.
#
# ...
#
#
#
# [!!]Indexing page: 2038
#
# [%] Indexed 18 Images on Page 2038.
#
# ...
#
#
#
# [!!]Indexing page: 2039
#
# ...

# %%
downloader.download("laptop_computer", limit=500,
                    output_dir=folder_path,
                    adult_filter_off=False,
                    force_replace=False,
                    timeout=60)
